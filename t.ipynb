# %%
import rasterio
import numpy as np
import matplotlib.pyplot as plt
from skimage.morphology import remove_small_objects
import math

# %%
with rasterio.open('BAND2.tif') as src:  # Red band Rename band2 to 3
    red = src.read(1)
    full_height, full_width = red.shape
    
with rasterio.open('BAND4.tif') as src:  # NIR band
    nir = src.read(1)

# %%
fcc_tile = np.dstack((nir, red, np.zeros_like(red)))
#plot.imshow(image)

plt.imshow(red)
